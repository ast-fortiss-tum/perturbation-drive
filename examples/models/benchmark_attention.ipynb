# %%
# change working directory to the '/Users/hannesleonhard/Documents/BachelorWInfo/Robustness-SDC/PerturbationDrive/'
import os
os.chdir('/Users/hannesleonhard/Documents/BachelorWInfo/Robustness-SDC/PerturbationDrive/')
os.getcwd()
# Out:
# '/Users/hannesleonhard/Documents/BachelorWInfo/Robustness-SDC/PerturbationDrive'

# %%
from perturbationdrive import CustomRoadGenerator
from perturbationdrive.RoadGenerator.Roads.road_visualizer import visualize_road

# road 1 is straight
road1_angles = [0, 0, 0, 0, 0, 0, 0, 0]
road1_segments = [25, 25, 25, 25, 25, 25, 25, 25]

# road 2-10 are a set of rooads with different smoothnes and turns
road2_angles = [0, -20, -10, -11, -13, -25, -24, 4]
road2_segments = [25, 25, 25, 25, 25, 25, 25, 25]

road3_angles = [0, 24, 24, -5, -7, -24, -20, 17]
road3_segments = [25, 25, 25, 25, 25, 25, 25, 25]

road4_angles = [0, 6, 8, 20, -3, 20, -13, -27]
road4_segments = [25, 25, 25, 25, 25, 25, 25, 25]

road5_angles = [0, -2, -30, -8, 2, 2, 4, -30]
road5_segments = [25, 25, 25, 25, 25, 25, 25, 25]

road6_angles = [0, 0, 27, 35, -35, -35, -6, -35]
road6_segments = [25, 25, 25, 25, 25, 25, 25, 25]

road7_angles = [0, -27, -20, 35, 23, -3, 4, -35]
road7_segments = [25, 25, 25, 25, 25, 25, 25, 25]

road8_angles = [0, 30, 30, -30, 32, -32, 25, -12]
road8_segments = [25, 25, 25, 25, 25, 25, 25, 25]

road9_angles = [0, -35, -20, -35, 35, 35, 35, -35]
road9_segments = [25, 25, 25, 25, 25, 25, 25, 25]

road10_angles = [0, -35, 0, -17, -35, 35, 6, -22]
road10_segments = [25, 25, 25, 25, 25, 25, 25, 25]


angles = [
    road1_angles,
    road2_angles,
    road3_angles,
    road4_angles,
    road5_angles,
    road6_angles,
    road7_angles,
    road8_angles,
    road9_angles,
    road10_angles,
]
segments = [
    road1_segments,
    road2_segments,
    road3_segments,
    road4_segments,
    road5_segments,
    road6_segments,
    road7_segments,
    road8_segments,
    road9_segments,
    road10_segments,
]

road_gen = CustomRoadGenerator()
# Out:
# /Users/hannesleonhard/micromamba/envs/donkey_opensbt/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /Users/hannesleonhard/micromamba/envs/donkey_opensbt/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.9.2 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# pygame 2.5.2 (SDL 2.28.3, Python 3.9.18)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# setup a sdsandbox simulator
from examples.self_driving_sandbox_donkey.sdsandbox_simulator import SDSandboxSimulator

simulator_sdsandbox = SDSandboxSimulator(
    simulator_exe_path="./examples/self_driving_sandbox_donkey/sim/donkey-sim.app",
    host="127.0.0.1",
    port=9091,
    show_image_cb=False,
)

# %%
from perturbationdrive import PerturbationDrive
from examples.models.dave2_agent import Dave2Agent
from examples.models.epoch_agent import EpochAgent
from examples.models.chauffeur_agent import ChauffeurAgent

dave2 = Dave2Agent()
dave2.name = "VanillaDAVE2"
# Out:
# Using model: ./examples/models/dave_90k_v1.h5

# %%
perturbations_attention = [
    "gaussian_noise",
    "poisson_noise",
    "impulse_noise",
    "defocus_blur",
    "glass_blur",
    "motion_blur",
    "increase_brightness",
    "contrast",
    "elastic",
    "pixelate",
    "jpeg_filter",
    "shear_image",
    "translate_image",
    "scale_image",
    "rotate_image",
    "splatter_mapping",
    "dotted_lines_mapping",
    "zigzag_mapping",
    "canny_edges_mapping",
    "speckle_noise_filter",
    "false_color_filter",
    "high_pass_filter",
    "low_pass_filter",
    "phase_scrambling",
    "histogram_equalisation",
    "reflection_filter",
    "white_balance_filter",
    "sharpen_filter",
    "grayscale_filter",
    "fog_filter",
    "frost_filter",
    "snow_filter",
    "posterize_filter",
    "cutout_filter",
    "sample_pairing_filter",
    "gaussian_blur",
    "saturation_filter",
    "saturation_decrease_filter",
]

# %%
from perturbationdrive import Scenario
import gc
import random

random.seed(42)


try:
    benchmark = PerturbationDrive(simulator=simulator_sdsandbox, ads=dave2)
    benchmark.simulator.connect()
    starting_pos = benchmark.simulator.initial_pos

    # init all scenarios
    scenarios = []
    counter = 0
    # iterate over all agents
    for angle, segment in zip(angles, segments):
        # run all perturbations for each road
        waypoints = road_gen.generate(
            starting_pos=starting_pos, angles=angle, seg_length=segment
        )
        scenarios = []
        for func in perturbations_attention:
            for i in range(5):
                scenarios.append(
                    Scenario(
                        waypoints=waypoints,
                        perturbation_function=func,
                        perturbation_scale=i,
                    )
                )
        print(f"Starting Agent {dave2.name} on road {angle}")
        # run the benchmark
        model = dave2.model
        attention_map = {
            "map": "grad_cam",
            "model": model,
            "threshold": 0.5,
            "layer": "conv2d_5",
            "attention_perturbation": "perturb_highest_n_attention_regions",
        }
        res = benchmark.simulate_scenarios(
            scenarios=scenarios,
            attention_map=attention_map,
            log_dir=f"./logs/donkey_highest_50_attention_road{counter}_{dave2.name}.json",
        )
        del res
        gc.collect()
        # update attention map
        attention_map["attention_perturbation"] = "perturb_lowest_n_attention_regions"
        res = benchmark.simulate_scenarios(
            scenarios=scenarios,
            attention_map=attention_map,
            log_dir=f"./logs/donkey_lowest_50_attention_road{counter}_{dave2.name}.json",
        )
        del res
        gc.collect()
        # update attention map
        attention_map["attention_perturbation"] = "perturb_random_n_attention_regions"
        res = benchmark.simulate_scenarios(
            scenarios=scenarios,
            attention_map=attention_map,
            log_dir=f"./logs/donkey_random_50_attention_road{counter}_{dave2.name}.json",
        )
        del res
        gc.collect()
        counter += 1
        print(f"Finished Agent {dave2.name} on road {angle}")
except Exception as e:
    print(e)
finally:
    benchmark.simulator.tear_down()
# Out:
# INFO:DonkeyProcess:This is the launch string /Users/hannesleonhard/Documents/BachelorWInfo/Robustness-SDC/PerturbationDrive/./examples/self_driving_sandbox_donkey/sim/donkey-sim.app/Contents/MacOS/Simulator
# [UnityMemory] Configuration Parameters - Can be set up in boot.config
#     "memorysetup-bucket-allocator-granularity=16"
#     "memorysetup-bucket-allocator-bucket-count=8"
#     "memorysetup-bucket-allocator-block-size=4194304"
#     "memorysetup-bucket-allocator-block-count=1"
#     "memorysetup-main-allocator-block-size=16777216"
#     "memorysetup-thread-allocator-block-size=16777216"
#     "memorysetup-gfx-main-allocator-block-size=16777216"
#     "memorysetup-gfx-thread-allocator-block-size=16777216"
#     "memorysetup-cache-allocator-block-size=4194304"
#     "memorysetup-typetree-allocator-block-size=2097152"
#     "memorysetup-profiler-bucket-allocator-granularity=16"
#     "memorysetup-profiler-bucket-allocator-bucket-count=8"
#     "memorysetup-profiler-bucket-allocator-block-size=4194304"
#     "memorysetup-profiler-bucket-allocator-block-count=1"
#     "memorysetup-profiler-allocator-block-size=16777216"
#     "memorysetup-profiler-editor-allocator-block-size=1048576"
#     "memorysetup-temp-allocator-size-main=4194304"
#     "memorysetup-job-temp-allocator-block-size=2097152"
#     "memorysetup-job-temp-allocator-block-size-background=1048576"
#     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
#     "memorysetup-allocator-temp-initial-block-size-main=262144"
#     "memorysetup-allocator-temp-initial-block-size-worker=262144"
#     "memorysetup-temp-allocator-size-background-worker=32768"
#     "memorysetup-temp-allocator-size-job-worker=262144"
#     "memorysetup-temp-allocator-size-preload-manager=262144"
#     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
#     "memorysetup-temp-allocator-size-audio-worker=65536"
#     "memorysetup-temp-allocator-size-cloud-worker=32768"
#     "memorysetup-temp-allocator-size-gfx=262144"
# INFO:DonkeyProcess:donkey subprocess started
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:DonkeySimMsgHandler:DonkeySimMsgHandler: ----- Car Created With Data {'msg_type': 'car_loaded'} -----
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# Starting Agent VanillaDAVE2 on road [0, 0, 0, 0, 0, 0, 0, 0]
# ----- Finished Perturbation-Controller set up -----
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 18.70
# fps 19.72
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.74
# fps 19.72
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.73
# fps 19.70
# fps 19.73
# fps 19.72
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.74
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.73
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.76
# fps 19.74
# fps 19.71
# fps 19.73
# fps 19.73
# fps 19.71
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.75
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.72
# fps 19.74
# fps 19.72
# fps 19.69
# fps 19.72
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.74
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.71
# SDSandBox: Finished scenario
# fps 19.72
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.69
# fps 19.74
# fps 19.72
# fps 19.69
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.74
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.77
# fps 19.69
# fps 19.74
# fps 19.71
# fps 19.73
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.74
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.65
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.76
# fps 19.70
# fps 19.73
# fps 19.73
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.69
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.73
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.65
# fps 19.75
# fps 19.69
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.69
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.73
# fps 19.72
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.72
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.71
# fps 19.70
# fps 19.75
# fps 19.73
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.74
# fps 19.73
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.77
# fps 19.71
# fps 19.72
# fps 19.74
# fps 19.72
# fps 19.74
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.80
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.76
# fps 19.70
# fps 19.68
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.72
# fps 19.71
# fps 19.73
# fps 19.73
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.73
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.74
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.76
# fps 19.72
# fps 19.74
# fps 19.71
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.74
# fps 19.73
# fps 19.73
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.73
# fps 19.73
# fps 19.73
# fps 19.72
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.77
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.75
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.73
# fps 19.73
# fps 19.74
# fps 19.70
# fps 19.75
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.73
# fps 19.73
# fps 19.69
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.71
# fps 19.68
# fps 19.72
# fps 19.74
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.76
# fps 19.73
# fps 19.73
# fps 19.75
# fps 19.72
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.71
# fps 19.71
# fps 19.74
# fps 19.73
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.76
# fps 19.71
# fps 19.73
# fps 19.73
# fps 19.73
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.72
# fps 19.68
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.70
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.74
# fps 19.70
# fps 19.69
# fps 19.71
# fps 19.69
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.75
# fps 19.71
# fps 19.74
# fps 19.71
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.74
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.70
# SDSandBox: Finished scenario
# fps 19.64
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.70
# fps 19.71
# fps 19.68
# fps 19.70
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.52
# fps 19.78
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.75
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.71
# fps 19.68
# fps 19.73
# fps 19.71
# fps 19.69
# SDSandBox: Finished scenario
# fps 19.55
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.72
# fps 19.67
# fps 19.71
# fps 19.73
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.70
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.76
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.71
# fps 19.75
# fps 19.71
# fps 19.72
# fps 19.75
# fps 19.70
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.77
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.69
# fps 19.73
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.76
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.73
# fps 19.68
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.69
# fps 19.75
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.69
# fps 19.73
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.73
# fps 19.69
# fps 19.69
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.72
# fps 19.69
# fps 19.71
# fps 19.68
# fps 19.71
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.69
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.74
# fps 19.73
# fps 19.70
# fps 19.72
# fps 19.62
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.75
# fps 19.72
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.70
# fps 19.70
# fps 19.73
# fps 19.70
# fps 19.69
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.74
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.73
# fps 19.70
# fps 19.73
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.77
# fps 19.71
# fps 19.76
# fps 19.71
# fps 19.68
# fps 19.70
# fps 19.71
# fps 19.69
# fps 19.63
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.74
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.74
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.66
# fps 19.73
# fps 19.73
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.69
# fps 19.71
# fps 19.73
# fps 19.75
# fps 19.74
# fps 19.70
# fps 19.71
# fps 19.73
# fps 19.73
# fps 19.72
# fps 19.68
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.77
# fps 19.72
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.73
# fps 19.72
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.70
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.73
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.75
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.74
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.79
# fps 19.74
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.66
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.74
# fps 19.71
# fps 19.72
# fps 19.75
# fps 19.70
# fps 19.70
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.72
# fps 19.68
# fps 19.69
# fps 19.70
# fps 19.73
# fps 19.71
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.74
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.66
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.73
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.74
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.66
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.74
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.74
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.76
# fps 19.70
# fps 19.76
# fps 19.71
# fps 19.72
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.74
# fps 19.69
# fps 19.74
# fps 19.73
# fps 19.76
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.77
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.72
# fps 19.69
# fps 19.73
# fps 19.74
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.76
# fps 19.71
# fps 19.46
# fps 19.72
# fps 19.69
# fps 19.70
# SDSandBox: Finished scenario
# fps 19.65
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.68
# fps 19.72
# fps 19.73
# fps 19.70
# fps 19.75
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.75
# fps 19.74
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.68
# fps 19.71
# fps 19.68
# INFO:SDSandBoxSimulator:SDSandBox: Timeout after 90s
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.71
# fps 19.74
# fps 19.71
# fps 19.73
# fps 19.61
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.69
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.70
# fps 19.73
# fps 19.75
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.75
# fps 19.71
# fps 19.74
# fps 19.72
# fps 19.70
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.74
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.69
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.74
# fps 19.72
# fps 19.73
# fps 19.69
# fps 19.72
# fps 19.73
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Timeout after 90s
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.24
# fps 19.74
# fps 19.72
# fps 19.71
# fps 19.74
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.77
# fps 19.71
# fps 19.74
# fps 19.74
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.74
# fps 19.72
# fps 19.61
# fps 19.82
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.74
# fps 19.65
# fps 19.75
# fps 19.70
# fps 19.69
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.71
# fps 19.72
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.70
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.76
# fps 19.74
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.75
# fps 19.73
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.74
# fps 19.71
# fps 19.74
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.75
# fps 19.72
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.71
# fps 19.72
# fps 19.69
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.74
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.74
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.77
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.73
# fps 19.75
# fps 19.70
# fps 19.69
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.72
# fps 19.72
# fps 19.74
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.76
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.73
# fps 19.73
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.75
# fps 19.72
# fps 19.73
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.74
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.74
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.74
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.68
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.68
# fps 19.70
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.71
# fps 19.68
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.66
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.73
# fps 19.71
# fps 19.74
# fps 19.71
# fps 19.73
# fps 19.69
# fps 19.72
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.68
# fps 19.73
# fps 19.70
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.74
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.69
# fps 19.48
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.74
# fps 19.72
# fps 19.72
# fps 19.66
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.76
# fps 19.72
# fps 19.71
# fps 19.74
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.71
# fps 19.69
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.73
# fps 19.69
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.73
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.76
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.67
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.65
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.77
# fps 19.72
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.75
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.73
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.69
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.73
# fps 19.67
# fps 19.68
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.62
# fps 19.75
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.63
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.73
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.42
# fps 19.90
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.73
# fps 19.71
# fps 19.68
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.70
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.77
# fps 19.56
# fps 19.72
# fps 19.69
# fps 19.71
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.74
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.72
# fps 19.69
# fps 19.73
# fps 19.69
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.75
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.70
# fps 19.68
# fps 19.73
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.78
# fps 19.69
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.75
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.74
# fps 19.70
# fps 19.74
# fps 19.73
# fps 19.74
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.68
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.70
# fps 19.69
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.70
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.75
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.73
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.72
# fps 19.75
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.74
# fps 19.67
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.77
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.74
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.74
# fps 19.75
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.77
# fps 19.73
# fps 19.70
# fps 19.73
# fps 19.68
# fps 19.74
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.76
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.66
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.78
# fps 19.71
# fps 19.73
# fps 19.73
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.76
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.72
# fps 19.74
# fps 19.71
# fps 19.71
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.69
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.72
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.73
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.74
# fps 19.72
# fps 19.70
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.70
# fps 19.74
# fps 19.70
# fps 19.68
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.70
# fps 19.68
# fps 19.67
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.73
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.71
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.76
# fps 19.73
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.69
# fps 19.69
# fps 19.73
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.73
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.76
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.72
# fps 19.69
# fps 19.72
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.61
# fps 19.78
# fps 19.72
# fps 19.74
# fps 19.70
# fps 19.75
# fps 19.72
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.78
# fps 19.73
# fps 19.72
# fps 19.76
# fps 19.71
# fps 19.73
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.64
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.77
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.74
# fps 19.69
# fps 19.74
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.76
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.69
# fps 19.73
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.69
# fps 19.73
# fps 19.72
# fps 19.73
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.73
# fps 19.70
# fps 19.73
# fps 19.73
# fps 19.72
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.62
# fps 19.71
# fps 19.76
# fps 19.73
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.75
# fps 19.71
# fps 19.74
# fps 19.72
# fps 19.72
# fps 19.69
# fps 19.73
# fps 19.74
# fps 19.70
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.72
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.72
# fps 19.69
# fps 19.72
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.74
# fps 19.73
# fps 19.71
# fps 19.73
# fps 19.74
# fps 19.75
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.69
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.75
# fps 19.72
# fps 19.69
# fps 19.73
# fps 19.70
# fps 19.69
# fps 19.69
# fps 19.72
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.69
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.69
# fps 19.72
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.73
# fps 19.72
# fps 19.69
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.75
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.68
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.72
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.69
# fps 19.73
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.73
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.66
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.73
# fps 19.71
# fps 19.69
# fps 19.68
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.66
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.69
# fps 19.70
# fps 19.72
# fps 19.69
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.75
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.66
# ----- Finished Perturbation-Controller set up -----
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.77
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.68
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.70
# fps 19.73
# fps 19.70
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.75
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.77
# fps 19.69
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.76
# fps 19.70
# fps 19.69
# fps 19.72
# fps 19.75
# fps 19.72
# fps 19.70
# fps 19.74
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.76
# fps 19.72
# fps 19.73
# fps 19.70
# fps 19.72
# fps 19.72
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.75
# fps 19.72
# fps 19.75
# fps 19.73
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.69
# fps 19.74
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.73
# fps 19.69
# fps 19.69
# fps 19.70
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.76
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.73
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.76
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.77
# fps 19.72
# fps 19.71
# fps 19.75
# fps 19.70
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.75
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.75
# fps 19.70
# fps 19.71
# fps 19.69
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.73
# fps 19.73
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.79
# fps 19.72
# fps 19.74
# fps 19.71
# fps 19.72
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.77
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.69
# fps 19.70
# fps 19.71
# fps 19.73
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.76
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.74
# fps 19.69
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.68
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.76
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.74
# fps 19.70
# fps 19.70
# fps 19.69
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.75
# fps 19.70
# fps 19.73
# fps 19.70
# fps 19.68
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.74
# fps 19.73
# fps 19.70
# fps 19.69
# fps 19.70
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.69
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.72
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.71
# fps 19.73
# fps 19.68
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.77
# fps 19.69
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.78
# fps 19.68
# fps 19.72
# fps 19.70
# fps 19.69
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.71
# fps 19.74
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.75
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.69
# fps 19.69
# fps 19.73
# fps 19.72
# fps 19.74
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.69
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Timeout after 90s
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.72
# fps 19.68
# fps 19.71
# fps 19.77
# fps 19.68
# fps 19.72
# fps 19.71
# fps 19.75
# fps 19.71
# fps 19.73
# fps 19.70
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.70
# fps 19.70
# fps 19.70
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.73
# fps 19.74
# fps 19.72
# fps 19.74
# fps 19.70
# fps 19.69
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.76
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.70
# fps 19.76
# SDSandBox: Finished scenario
# fps 19.66
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.76
# fps 19.70
# fps 19.74
# fps 19.74
# fps 19.69
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.68
# fps 19.72
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.73
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.69
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.65
# fps 19.75
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.76
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.70
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# ...
# fps 16.75
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.99
# fps 16.55
# fps 16.64
# fps 16.67
# fps 16.63
# fps 16.71
# fps 16.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.89
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.92
# fps 16.63
# fps 16.54
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 17.07
# fps 16.54
# fps 16.63
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.93
# fps 16.74
# fps 16.54
# fps 16.65
# fps 16.70
# fps 16.69
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.98
# fps 16.63
# fps 16.64
# fps 16.70
# fps 16.68
# fps 16.66
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 17.00
# fps 16.68
# fps 16.59
# fps 16.60
# fps 16.58
# fps 16.64
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.93
# fps 16.69
# fps 16.61
# fps 16.65
# fps 16.62
# fps 16.71
# fps 16.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.95
# fps 16.73
# fps 16.62
# fps 16.64
# fps 16.67
# fps 16.69
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.80
# fps 16.79
# fps 16.58
# fps 16.62
# fps 16.63
# fps 16.65
# fps 16.68
# fps 16.64
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 17.01
# fps 16.62
# fps 16.60
# fps 16.66
# fps 16.67
# fps 16.63
# fps 16.51
# fps 16.65
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.82
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 17.01
# fps 16.59
# fps 16.61
# fps 16.64
# fps 16.56
# fps 16.67
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.83
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.85
# fps 16.58
# fps 16.59
# fps 16.60
# fps 16.67
# fps 16.66
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.82
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.91
# fps 16.57
# fps 16.60
# fps 16.64
# fps 16.66
# fps 16.65
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.82
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.93
# fps 16.61
# fps 16.67
# fps 16.69
# fps 16.69
# fps 16.72
# fps 16.75
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 17.02
# fps 16.63
# fps 16.56
# fps 16.67
# fps 16.69
# fps 16.70
# fps 16.64
# fps 16.76
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.94
# fps 16.83
# fps 16.62
# fps 16.66
# fps 16.70
# fps 16.75
# fps 16.72
# fps 16.78
# fps 16.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.89
# fps 16.69
# fps 16.66
# fps 16.64
# fps 16.66
# fps 16.67
# fps 16.59
# fps 16.68
# fps 16.75
# fps 16.74
# fps 16.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.83
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.91
# fps 16.61
# fps 16.64
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.99
# fps 16.59
# fps 16.60
# fps 16.66
# fps 16.61
# fps 16.70
# fps 16.63
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.76
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.87
# fps 16.54
# fps 16.62
# fps 16.65
# fps 16.64
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 17.02
# fps 16.58
# fps 16.63
# fps 16.61
# fps 16.65
# SDSandBox: Finished scenario
# fps 16.84
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.84
# fps 16.57
# fps 16.55
# fps 16.64
# fps 16.67
# fps 16.65
# fps 16.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.95
# fps 16.59
# fps 16.56
# fps 16.60
# fps 16.58
# fps 16.61
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.99
# fps 16.60
# SDSandBox: Finished scenario
# fps 16.64
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.99
# fps 16.60
# fps 16.56
# fps 16.64
# fps 16.60
# fps 16.60
# fps 16.68
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.99
# fps 16.62
# fps 16.55
# fps 16.56
# fps 16.63
# fps 16.62
# fps 16.65
# fps 16.62
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 17.01
# fps 16.52
# fps 16.58
# fps 16.60
# fps 16.58
# fps 16.64
# fps 16.62
# fps 16.55
# fps 16.62
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.89
# fps 16.56
# fps 16.54
# fps 16.51
# fps 16.60
# fps 16.58
# fps 16.62
# SDSandBox: Finished scenario
# fps 16.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.95
# fps 16.56
# fps 16.57
# fps 16.62
# fps 16.61
# fps 16.56
# fps 16.64
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.76
# fps 16.81
# fps 16.58
# fps 16.62
# fps 16.64
# fps 16.55
# fps 16.67
# fps 16.64
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.98
# fps 16.57
# fps 16.49
# fps 16.61
# fps 16.58
# fps 16.64
# fps 16.63
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.75
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.88
# fps 16.47
# fps 16.61
# fps 16.61
# fps 16.59
# fps 16.67
# fps 16.66
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.91
# fps 16.57
# fps 16.53
# fps 16.61
# fps 16.60
# fps 16.59
# fps 16.59
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.54
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.93
# fps 16.60
# fps 16.54
# fps 16.60
# fps 16.54
# fps 16.64
# fps 16.65
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.91
# fps 16.75
# fps 16.56
# fps 16.61
# fps 16.59
# fps 16.54
# fps 16.65
# fps 16.62
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.88
# fps 16.74
# fps 16.55
# fps 16.56
# fps 16.60
# fps 16.60
# fps 16.63
# fps 16.60
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.77
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.81
# fps 16.54
# fps 16.58
# fps 16.59
# fps 16.61
# fps 16.62
# fps 16.67
# fps 16.64
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.74
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.87
# fps 16.52
# fps 16.56
# fps 16.58
# fps 16.57
# fps 16.63
# fps 16.62
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.72
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.90
# fps 16.55
# fps 16.56
# fps 16.59
# fps 16.64
# fps 16.58
# fps 16.58
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.81
# fps 16.73
# fps 16.51
# fps 16.56
# fps 16.66
# fps 16.55
# fps 16.59
# fps 16.62
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.95
# fps 16.50
# fps 16.56
# fps 16.60
# fps 16.60
# fps 16.60
# fps 16.63
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.73
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.82
# fps 16.53
# fps 16.54
# fps 16.59
# fps 16.58
# fps 16.62
# fps 16.63
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 17.01
# fps 16.56
# fps 16.46
# fps 16.56
# fps 16.58
# fps 16.62
# fps 16.60
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.81
# fps 16.76
# fps 16.56
# fps 16.60
# fps 16.58
# fps 16.64
# fps 16.62
# fps 16.61
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.96
# fps 16.59
# fps 16.52
# fps 16.59
# fps 16.60
# fps 16.64
# fps 16.64
# fps 16.64
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.93
# fps 16.55
# fps 16.57
# fps 16.60
# fps 16.62
# fps 16.61
# fps 16.61
# fps 16.63
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.97
# fps 16.56
# fps 16.51
# fps 16.25
# fps 16.57
# fps 16.63
# fps 16.57
# fps 16.61
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.84
# fps 16.67
# fps 16.52
# fps 16.54
# fps 16.58
# fps 16.57
# fps 16.64
# fps 16.66
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.86
# fps 16.56
# fps 16.54
# fps 16.63
# fps 16.60
# fps 16.57
# fps 16.62
# fps 16.61
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 17.00
# fps 16.57
# fps 16.54
# fps 16.56
# fps 16.65
# fps 16.62
# fps 16.56
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.79
# fps 16.48
# fps 16.56
# fps 16.59
# fps 16.62
# fps 16.62
# fps 16.62
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.84
# fps 16.56
# fps 16.55
# fps 16.59
# fps 16.59
# fps 16.62
# fps 16.66
# fps 16.62
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.94
# fps 16.54
# fps 16.54
# fps 16.58
# fps 16.61
# fps 16.60
# fps 16.59
# fps 16.58
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.81
# fps 16.49
# fps 16.54
# fps 16.62
# fps 16.60
# fps 16.61
# fps 16.65
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.65
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.81
# fps 16.54
# fps 16.55
# fps 16.53
# fps 16.56
# fps 16.55
# fps 16.64
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.75
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.82
# fps 16.44
# fps 16.56
# fps 16.59
# fps 16.60
# fps 16.56
# fps 16.62
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.88
# fps 16.71
# fps 16.34
# fps 16.52
# fps 16.53
# fps 16.56
# fps 16.55
# fps 16.61
# fps 16.52
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.91
# fps 16.55
# fps 16.45
# fps 16.57
# fps 16.57
# fps 16.53
# fps 16.62
# fps 16.56
# fps 16.57
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.56
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.85
# fps 16.49
# fps 16.54
# fps 16.52
# fps 16.51
# fps 16.55
# fps 16.61
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.74
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.75
# fps 16.49
# fps 16.52
# fps 16.56
# fps 16.54
# fps 16.52
# fps 16.55
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.83
# fps 16.55
# fps 16.51
# fps 16.53
# fps 16.51
# fps 16.56
# fps 16.49
# fps 16.49
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.98
# fps 16.42
# fps 16.39
# fps 16.47
# fps 16.18
# fps 16.39
# fps 16.54
# fps 16.54
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.75
# fps 16.48
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.86
# fps 16.51
# fps 16.50
# fps 16.49
# fps 16.62
# fps 16.56
# fps 16.55
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.73
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.72
# fps 16.49
# fps 16.41
# fps 16.56
# fps 16.55
# fps 16.58
# SDSandBox: Finished scenario
# fps 16.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.76
# fps 16.42
# fps 16.49
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.87
# fps 16.47
# fps 16.44
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.64
# fps 16.51
# fps 16.49
# SDSandBox: Finished scenario
# fps 16.58
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.74
# fps 16.48
# fps 16.51
# fps 16.53
# fps 16.49
# fps 16.53
# fps 16.58
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.81
# fps 16.49
# fps 16.48
# fps 16.50
# fps 16.52
# fps 16.55
# fps 16.57
# fps 16.56
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.90
# fps 16.44
# fps 16.44
# fps 16.51
# fps 16.55
# fps 16.53
# fps 16.57
# fps 16.56
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.76
# fps 16.67
# fps 16.42
# fps 16.42
# fps 16.53
# fps 16.49
# fps 16.50
# fps 16.49
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.79
# fps 16.69
# fps 16.49
# fps 16.47
# fps 16.44
# fps 16.51
# fps 16.53
# SDSandBox: Finished scenario
# fps 16.63
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.81
# fps 16.44
# fps 16.34
# fps 16.54
# fps 16.57
# fps 16.57
# fps 16.52
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.85
# fps 16.47
# fps 16.47
# fps 16.52
# fps 16.46
# fps 16.55
# fps 16.54
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.47
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.87
# fps 16.38
# fps 16.46
# fps 16.45
# fps 16.51
# fps 16.53
# fps 16.49
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.64
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.81
# fps 16.41
# fps 16.50
# fps 16.51
# fps 16.52
# fps 16.55
# fps 16.54
# fps 16.55
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.76
# fps 16.52
# fps 16.46
# fps 16.42
# fps 16.48
# fps 16.51
# fps 16.52
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.79
# fps 16.54
# fps 16.46
# fps 16.50
# fps 16.46
# fps 16.56
# fps 16.52
# fps 16.52
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.91
# fps 16.42
# fps 16.44
# fps 16.50
# fps 16.50
# fps 16.56
# fps 16.57
# fps 16.55
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.78
# fps 16.50
# fps 16.43
# fps 16.47
# fps 16.54
# fps 16.25
# fps 16.49
# fps 16.48
# fps 16.55
# fps 16.51
# fps 16.56
# fps 16.56
# fps 16.54
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.90
# fps 16.46
# fps 16.43
# fps 16.40
# fps 16.46
# fps 16.47
# fps 16.46
# fps 16.42
# fps 16.41
# fps 16.38
# fps 16.44
# fps 16.37
# fps 16.49
# fps 16.48
# fps 16.51
# INFO:SDSandBoxSimulator:SDSandBox: Timeout after 90s
# SDSandBox: Finished scenario
# fps 16.51
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.62
# fps 16.44
# fps 16.43
# fps 16.47
# fps 16.48
# fps 16.49
# fps 16.44
# fps 16.49
# fps 16.49
# fps 16.49
# fps 16.50
# fps 16.50
# fps 16.47
# fps 16.50
# fps 16.49
# INFO:SDSandBoxSimulator:SDSandBox: Timeout after 90s
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.71
# fps 16.52
# fps 16.38
# fps 16.52
# fps 16.48
# fps 16.45
# fps 16.53
# fps 16.50
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.83
# fps 16.43
# fps 16.43
# fps 16.50
# fps 16.47
# fps 16.53
# fps 16.54
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.53
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.81
# fps 16.44
# fps 16.36
# fps 16.47
# fps 16.40
# fps 16.50
# fps 16.51
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.70
# fps 16.64
# fps 16.38
# fps 16.46
# fps 16.49
# fps 16.51
# fps 16.54
# fps 16.46
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.90
# fps 16.44
# fps 16.45
# fps 16.50
# fps 16.47
# fps 16.51
# fps 16.50
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.59
# Finished Agent VanillaDAVE2 on road [0, -35, 0, -17, -35, 35, 6, -22]
# INFO:DonkeySimMsgHandler:DonkeySimMsgHandler: +++++ Warning: Donkey Sim Disconnected +++++
# INFO:DonkeyProcess:Closing donkey sim subprocess

# %% [markdown]
# ### Dummy Setup to test perturbations

# %%
from perturbationdrive import Scenario
import gc
import traceback

try:
    benchmark = PerturbationDrive(simulator=simulator_sdsandbox, ads=dave2)
    benchmark.simulator.connect()
    starting_pos = benchmark.simulator.initial_pos

    # init all scenarios
    scenarios = []
    counter = 0
    # iterate over all agents
    angle = angles[0]
    segment = segments[0]
    # run all perturbations for each road
    print(f"Angles {angle} and length {segment}")
    waypoints = road_gen.generate(
        starting_pos=starting_pos, angles=angle, seg_length=segment
    )
    scenarios = []
    scenarios.append(
        Scenario(
            waypoints=waypoints,
            perturbation_function="zigzag_mapping",
            perturbation_scale=4,
        )
    )
    print(f"Starting Agent {dave2.name} on road {angle}")
    # run the benchmark
    model = dave2.model
    attention_map = {
        "map": "grad_cam",
        "model": model,
        "threshold": 0.5,
        "layer": "conv2d_5",
        "attention_perturbation": "perturb_highest_n_attention_regions",
    }
    res = benchmark.simulate_scenarios(
        scenarios=scenarios,
        attention_map=attention_map,
        log_dir=None,
    )
    del res
    gc.collect()
    # update attention map
    attention_map["attention_perturbation"] = "perturb_lowest_n_attention_regions"
    res = benchmark.simulate_scenarios(
        scenarios=scenarios,
        attention_map=attention_map,
        log_dir=None,
    )
    del res
    gc.collect()
    # update attention map
    attention_map["attention_perturbation"] = "perturb_random_n_attention_regions"
    res = benchmark.simulate_scenarios(
        scenarios=scenarios,
        attention_map=attention_map,
        log_dir=None,
    )
    del res
    gc.collect()
    counter += 1
    print(f"Finished Agent {dave2.name} on road {angle}")
except Exception as e:
    print(e)
    traceback.print_exc()
finally:
    benchmark.simulator.tear_down()
    del benchmark
# Out:
# INFO:DonkeyProcess:This is the launch string /Users/hannesleonhard/Documents/BachelorWInfo/Robustness-SDC/PerturbationDrive/./examples/self_driving_sandbox_donkey/sim/donkey-sim.app/Contents/MacOS/Simulator
# [UnityMemory] Configuration Parameters - Can be set up in boot.config
#     "memorysetup-bucket-allocator-granularity=16"
#     "memorysetup-bucket-allocator-bucket-count=8"
#     "memorysetup-bucket-allocator-block-size=4194304"
#     "memorysetup-bucket-allocator-block-count=1"
#     "memorysetup-main-allocator-block-size=16777216"
#     "memorysetup-thread-allocator-block-size=16777216"
#     "memorysetup-gfx-main-allocator-block-size=16777216"
#     "memorysetup-gfx-thread-allocator-block-size=16777216"
#     "memorysetup-cache-allocator-block-size=4194304"
#     "memorysetup-typetree-allocator-block-size=2097152"
#     "memorysetup-profiler-bucket-allocator-granularity=16"
#     "memorysetup-profiler-bucket-allocator-bucket-count=8"
#     "memorysetup-profiler-bucket-allocator-block-size=4194304"
#     "memorysetup-profiler-bucket-allocator-block-count=1"
#     "memorysetup-profiler-allocator-block-size=16777216"
#     "memorysetup-profiler-editor-allocator-block-size=1048576"
#     "memorysetup-temp-allocator-size-main=4194304"
#     "memorysetup-job-temp-allocator-block-size=2097152"
#     "memorysetup-job-temp-allocator-block-size-background=1048576"
#     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
#     "memorysetup-allocator-temp-initial-block-size-main=262144"
#     "memorysetup-allocator-temp-initial-block-size-worker=262144"
#     "memorysetup-temp-allocator-size-background-worker=32768"
#     "memorysetup-temp-allocator-size-job-worker=262144"
#     "memorysetup-temp-allocator-size-preload-manager=262144"
#     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
#     "memorysetup-temp-allocator-size-audio-worker=65536"
#     "memorysetup-temp-allocator-size-cloud-worker=32768"
#     "memorysetup-temp-allocator-size-gfx=262144"
# INFO:DonkeyProcess:donkey subprocess started
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:DonkeySimMsgHandler:DonkeySimMsgHandler: ----- Car Created With Data {'msg_type': 'car_loaded'} -----
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# Angles [0, 0, 0, 0, 0, 0, 0, 0] and length [25, 25, 25, 25, 25, 25, 25, 25]
# Starting Agent VanillaDAVE2 on road [0, 0, 0, 0, 0, 0, 0, 0]
# ----- Finished Perturbation-Controller set up -----
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 18.72
# fps 19.72
# fps 19.74
# fps 19.74
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# ----- Finished Perturbation-Controller set up -----
# INFO:SDSandBoxSimulator:Reset the scenario
# threshold is 0.0
# will perturb 44116
# threshold is 0.0
# will perturb 44441
# threshold is 0.0
# will perturb 42701
# threshold is 0.0
# will perturb 41826
# threshold is 0.0
# will perturb 42382
# threshold is 0.0
# will perturb 42224
# threshold is 0.0
# will perturb 42297
# threshold is 0.0
# will perturb 42362
# threshold is 0.0
# will perturb 41344
# threshold is 0.0
# will perturb 41250
# threshold is 0.0
# will perturb 42227
# threshold is 0.0
# will perturb 42378
# threshold is 0.0
# will perturb 42418
# threshold is 0.0
# will perturb 41783
# threshold is 0.0
# will perturb 41210
# threshold is 0.0
# will perturb 41808
# threshold is 0.0
# will perturb 42004
# threshold is 0.0
# will perturb 42661
# threshold is 0.0
# will perturb 42028
# threshold is 0.0
# will perturb 42941
# threshold is 0.0
# will perturb 41721
# threshold is 0.0
# will perturb 41757
# threshold is 0.0
# will perturb 40265
# threshold is 0.0
# will perturb 42664
# threshold is 0.0
# will perturb 43311
# threshold is 0.0
# will perturb 42271
# threshold is 0.0
# will perturb 42302
# threshold is 0.0
# will perturb 42526
# threshold is 0.0
# will perturb 42431
# threshold is 0.0
# will perturb 42751
# threshold is 0.0
# will perturb 43251
# threshold is 0.0
# will perturb 44194
# threshold is 0.0
# will perturb 43717
# threshold is 0.0
# will perturb 42813
# threshold is 0.0
# will perturb 43341
# threshold is 0.0
# will perturb 43573
# threshold is 0.0
# will perturb 43635
# threshold is 0.0
# will perturb 42520
# threshold is 0.0
# will perturb 42137
# threshold is 0.0
# will perturb 42267
# threshold is 0.0
# will perturb 42830
# threshold is 0.0
# will perturb 43424
# threshold is 0.0
# will perturb 43594
# threshold is 0.0
# will perturb 42838
# threshold is 0.0
# will perturb 42932
# threshold is 0.0
# will perturb 42934
# threshold is 0.0
# will perturb 42510
# threshold is 0.0
# will perturb 43718
# threshold is 0.0
# will perturb 43701
# threshold is 0.0
# will perturb 43545
# fps 19.73
# threshold is 0.0
# will perturb 43501
# threshold is 0.0
# will perturb 43349
# threshold is 0.0
# will perturb 42358
# threshold is 0.0
# will perturb 43560
# threshold is 0.0
# will perturb 43243
# threshold is 0.0
# will perturb 43915
# threshold is 0.0
# will perturb 43975
# threshold is 0.0
# will perturb 45113
# threshold is 0.0
# will perturb 44233
# threshold is 0.0
# will perturb 45338
# threshold is 0.0
# will perturb 45697
# threshold is 0.0
# will perturb 45843
# threshold is 0.0
# will perturb 46755
# threshold is 0.0
# will perturb 46622
# threshold is 0.0
# will perturb 47521
# threshold is 0.0
# will perturb 47022
# threshold is 0.0
# will perturb 46262
# threshold is 0.0
# will perturb 46038
# threshold is 0.0
# will perturb 45578
# threshold is 0.0
# will perturb 45812
# threshold is 0.0
# will perturb 46318
# threshold is 0.0
# will perturb 46397
# threshold is 0.0
# will perturb 46417
# threshold is 0.0
# will perturb 47216
# threshold is 0.0
# will perturb 46677
# threshold is 0.0
# will perturb 45898
# threshold is 0.0
# will perturb 44606
# threshold is 0.0
# will perturb 45421
# threshold is 0.0
# will perturb 46502
# threshold is 0.0
# will perturb 46058
# threshold is 0.0
# will perturb 45654
# threshold is 0.0
# will perturb 45434
# threshold is 0.0
# will perturb 45388
# threshold is 0.0
# will perturb 46222
# threshold is 0.0
# will perturb 45599
# threshold is 0.0
# will perturb 44838
# threshold is 0.0
# will perturb 45647
# threshold is 0.0
# will perturb 45867
# threshold is 0.0
# will perturb 45019
# threshold is 0.0
# will perturb 45417
# threshold is 0.0
# will perturb 44210
# threshold is 0.0
# will perturb 44712
# threshold is 0.0
# will perturb 43995
# threshold is 0.0
# will perturb 42848
# threshold is 0.0
# will perturb 43122
# threshold is 0.0
# will perturb 41493
# threshold is 0.0
# will perturb 41976
# threshold is 0.0
# will perturb 42450
# threshold is 0.0
# will perturb 44116
# threshold is 0.0
# will perturb 43905
# threshold is 0.0
# will perturb 44092
# threshold is 0.0
# will perturb 44526
# threshold is 0.0
# will perturb 44208
# threshold is 0.0
# will perturb 45557
# threshold is 0.0
# will perturb 44303
# threshold is 0.0
# will perturb 44581
# threshold is 0.0
# will perturb 44232
# threshold is 0.0
# will perturb 44142
# threshold is 0.0
# will perturb 42619
# threshold is 0.0
# will perturb 43899
# threshold is 0.0
# will perturb 44597
# threshold is 0.0
# will perturb 44139
# threshold is 0.0
# will perturb 45884
# threshold is 0.0
# will perturb 47692
# threshold is 0.0
# will perturb 47364
# threshold is 0.0
# will perturb 47685
# threshold is 0.0
# will perturb 47220
# threshold is 0.0
# will perturb 47153
# threshold is 0.0
# will perturb 47484
# threshold is 0.0
# will perturb 47627
# threshold is 0.0
# will perturb 46832
# threshold is 0.0
# will perturb 45779
# threshold is 0.0
# will perturb 47129
# threshold is 0.0
# will perturb 48434
# threshold is 0.0
# will perturb 45702
# threshold is 0.0
# will perturb 45895
# threshold is 0.0
# will perturb 46400
# threshold is 0.0
# will perturb 45286
# threshold is 0.0
# will perturb 45427
# threshold is 0.0
# will perturb 45098
# threshold is 0.0
# will perturb 43830
# threshold is 0.0
# will perturb 44082
# threshold is 0.0
# will perturb 43301
# threshold is 0.0
# will perturb 43834
# threshold is 0.0
# will perturb 44554
# threshold is 0.0
# will perturb 42802
# threshold is 0.0
# will perturb 44254
# threshold is 0.0
# will perturb 44505
# threshold is 0.0
# will perturb 44646
# threshold is 0.0
# will perturb 43991
# threshold is 0.0
# will perturb 44535
# threshold is 0.0
# will perturb 44561
# threshold is 0.0
# will perturb 46279
# threshold is 0.0
# will perturb 43854
# threshold is 0.0
# will perturb 43062
# threshold is 0.0
# will perturb 43512
# threshold is 0.0
# will perturb 43661
# threshold is 0.0
# will perturb 44741
# threshold is 0.0
# will perturb 48000
# threshold is 0.0
# will perturb 47752
# threshold is 0.0
# will perturb 46653
# fps 19.71
# threshold is 0.0
# will perturb 46382
# threshold is 0.0
# will perturb 46435
# threshold is 0.0
# will perturb 46396
# threshold is 0.0
# will perturb 45696
# threshold is 0.0
# will perturb 47587
# threshold is 0.0
# will perturb 46293
# threshold is 0.0
# will perturb 45080
# threshold is 0.0
# will perturb 45844
# threshold is 0.0
# will perturb 45784
# threshold is 0.0
# will perturb 43649
# threshold is 0.0
# will perturb 46020
# threshold is 0.0
# will perturb 45172
# threshold is 0.0
# will perturb 44829
# threshold is 0.0
# will perturb 44565
# threshold is 0.0
# will perturb 43545
# threshold is 0.0
# will perturb 42288
# threshold is 0.0
# will perturb 44120
# threshold is 0.0
# will perturb 43558
# threshold is 0.0
# will perturb 43636
# threshold is 0.0
# will perturb 42834
# threshold is 0.0
# will perturb 44288
# threshold is 0.0
# will perturb 44522
# threshold is 0.0
# will perturb 44082
# threshold is 0.0
# will perturb 43233
# threshold is 0.0
# will perturb 44007
# threshold is 0.0
# will perturb 43963
# threshold is 0.0
# will perturb 44403
# threshold is 0.0
# will perturb 46748
# threshold is 0.0
# will perturb 48182
# threshold is 0.0
# will perturb 46933
# threshold is 0.0
# will perturb 46709
# threshold is 0.0
# will perturb 46431
# threshold is 0.0
# will perturb 45911
# threshold is 0.0
# will perturb 45934
# threshold is 0.0
# will perturb 46675
# threshold is 0.0
# will perturb 45962
# threshold is 0.0
# will perturb 46081
# threshold is 0.0
# will perturb 46232
# threshold is 0.0
# will perturb 44866
# threshold is 0.0
# will perturb 45231
# threshold is 0.0
# will perturb 43807
# threshold is 0.0
# will perturb 43622
# threshold is 0.0
# will perturb 42288
# threshold is 0.0
# will perturb 42838
# threshold is 0.0
# will perturb 42397
# threshold is 0.0
# will perturb 44777
# threshold is 0.0
# will perturb 44149
# threshold is 0.0
# will perturb 45113
# threshold is 0.0
# will perturb 44117
# threshold is 0.0
# will perturb 44922
# threshold is 0.0
# will perturb 44358
# threshold is 0.0
# will perturb 43315
# threshold is 0.0
# will perturb 42988
# threshold is 0.0
# will perturb 45022
# threshold is 0.0
# will perturb 47452
# threshold is 0.0
# will perturb 48060
# threshold is 0.0
# will perturb 46693
# threshold is 0.0
# will perturb 46010
# threshold is 0.0
# will perturb 46545
# threshold is 0.0
# will perturb 46071
# threshold is 0.0
# will perturb 45122
# threshold is 0.0
# will perturb 46943
# threshold is 0.0
# will perturb 43827
# threshold is 0.0
# will perturb 46760
# threshold is 0.0
# will perturb 43941
# threshold is 0.0
# will perturb 44454
# threshold is 0.0
# will perturb 45155
# threshold is 0.0
# will perturb 45024
# threshold is 0.0
# will perturb 41581
# threshold is 0.0
# will perturb 42574
# threshold is 0.0
# will perturb 42797
# threshold is 0.0
# will perturb 44881
# threshold is 0.0
# will perturb 43923
# threshold is 1.0135614502360113e-05
# will perturb 38400
# threshold is 0.0
# will perturb 44488
# threshold is 0.0
# will perturb 43880
# threshold is 0.0
# will perturb 44546
# threshold is 0.0
# will perturb 43622
# threshold is 0.0
# will perturb 42730
# threshold is 0.0
# will perturb 45470
# threshold is 0.0
# will perturb 47663
# threshold is 0.0
# will perturb 48491
# threshold is 0.0
# will perturb 47124
# threshold is 0.0
# will perturb 46914
# threshold is 0.0
# will perturb 46570
# threshold is 0.0
# will perturb 46637
# threshold is 0.0
# will perturb 46851
# threshold is 0.0
# will perturb 46746
# threshold is 0.0
# will perturb 45834
# threshold is 0.0
# will perturb 44370
# threshold is 0.0
# will perturb 44525
# threshold is 0.0
# will perturb 45474
# threshold is 0.0
# will perturb 43307
# threshold is 0.0
# will perturb 43967
# threshold is 0.0
# will perturb 42832
# threshold is 0.0
# will perturb 44157
# threshold is 0.0
# will perturb 45206
# threshold is 0.0
# will perturb 44762
# threshold is 0.0
# will perturb 43343
# threshold is 0.0
# will perturb 43978
# threshold is 0.0
# will perturb 44171
# fps 19.71
# threshold is 0.0
# will perturb 44653
# threshold is 0.0
# will perturb 44543
# threshold is 0.0
# will perturb 46628
# threshold is 0.0
# will perturb 49495
# threshold is 0.0
# will perturb 47972
# threshold is 0.0
# will perturb 46190
# threshold is 0.0
# will perturb 46509
# threshold is 0.0
# will perturb 46306
# threshold is 0.0
# will perturb 45185
# threshold is 0.0
# will perturb 45890
# threshold is 0.0
# will perturb 46070
# threshold is 0.0
# will perturb 47018
# threshold is 0.0
# will perturb 46244
# threshold is 0.0
# will perturb 44881
# threshold is 0.0
# will perturb 44520
# threshold is 0.0
# will perturb 43342
# threshold is 0.0
# will perturb 42907
# threshold is 0.0
# will perturb 43780
# threshold is 0.0
# will perturb 44566
# threshold is 0.0
# will perturb 43604
# threshold is 0.0
# will perturb 44599
# threshold is 0.0
# will perturb 44347
# threshold is 0.0
# will perturb 45392
# threshold is 0.0
# will perturb 43535
# threshold is 0.0
# will perturb 43422
# threshold is 0.0
# will perturb 45750
# threshold is 0.0
# will perturb 46893
# threshold is 0.0
# will perturb 48432
# threshold is 0.0
# will perturb 47092
# threshold is 0.0
# will perturb 47015
# threshold is 0.0
# will perturb 47007
# threshold is 0.0
# will perturb 46807
# threshold is 0.0
# will perturb 47179
# threshold is 0.0
# will perturb 46968
# threshold is 0.0
# will perturb 44467
# threshold is 0.0
# will perturb 45341
# threshold is 0.0
# will perturb 45350
# threshold is 0.0
# will perturb 43903
# threshold is 0.0
# will perturb 42609
# threshold is 0.0
# will perturb 43697
# threshold is 0.0
# will perturb 44808
# threshold is 0.0
# will perturb 43858
# threshold is 0.0
# will perturb 43929
# threshold is 0.0
# will perturb 44581
# threshold is 0.0
# will perturb 44032
# threshold is 0.0
# will perturb 44126
# threshold is 0.0
# will perturb 45039
# threshold is 0.0
# will perturb 47293
# threshold is 0.0
# will perturb 47783
# threshold is 0.0
# will perturb 48411
# threshold is 0.0
# will perturb 47758
# threshold is 0.0
# will perturb 47772
# threshold is 0.0
# will perturb 45062
# threshold is 0.0
# will perturb 47937
# threshold is 0.0
# will perturb 46280
# threshold is 0.0
# will perturb 46561
# threshold is 0.0
# will perturb 46430
# threshold is 0.0
# will perturb 43058
# threshold is 0.0
# will perturb 43787
# threshold is 0.0
# will perturb 43611
# threshold is 0.0
# will perturb 41835
# threshold is 0.0
# will perturb 45879
# threshold is 0.0
# will perturb 45110
# threshold is 0.0
# will perturb 44778
# threshold is 0.0
# will perturb 45615
# threshold is 0.0
# will perturb 44616
# threshold is 0.0
# will perturb 43179
# threshold is 0.0
# will perturb 44855
# threshold is 0.0
# will perturb 48141
# threshold is 0.0
# will perturb 45947
# threshold is 0.0
# will perturb 46085
# threshold is 0.0
# will perturb 44598
# threshold is 0.0
# will perturb 47455
# threshold is 0.0
# will perturb 46268
# threshold is 0.0
# will perturb 47719
# threshold is 0.0
# will perturb 47983
# threshold is 0.0
# will perturb 46225
# threshold is 0.0
# will perturb 45938
# threshold is 0.0
# will perturb 45408
# threshold is 0.0
# will perturb 44314
# threshold is 0.0
# will perturb 42151
# threshold is 0.0
# will perturb 42950
# fps 19.74
# threshold is 0.0
# will perturb 42846
# threshold is 0.0
# will perturb 43855
# threshold is 0.0
# will perturb 44132
# threshold is 0.0
# will perturb 43873
# threshold is 0.0
# will perturb 41780
# threshold is 0.0
# will perturb 43949
# threshold is 0.0
# will perturb 43708
# threshold is 0.0
# will perturb 44172
# threshold is 0.0
# will perturb 47361
# threshold is 0.0
# will perturb 47180
# threshold is 0.0
# will perturb 46891
# threshold is 0.0
# will perturb 47050
# threshold is 0.0
# will perturb 46406
# threshold is 0.0
# will perturb 45947
# threshold is 0.0
# will perturb 46546
# threshold is 0.0
# will perturb 44998
# threshold is 0.0
# will perturb 44937
# threshold is 0.0
# will perturb 44773
# threshold is 0.0
# will perturb 43084
# threshold is 0.0
# will perturb 44139
# threshold is 0.0
# will perturb 44180
# threshold is 0.0
# will perturb 43300
# threshold is 0.0
# will perturb 45525
# threshold is 0.0
# will perturb 44328
# threshold is 0.0
# will perturb 43074
# threshold is 0.0
# will perturb 45879
# threshold is 0.0
# will perturb 48723
# threshold is 0.0
# will perturb 48368
# threshold is 0.0
# will perturb 46518
# threshold is 0.0
# will perturb 46393
# threshold is 0.0
# will perturb 47681
# threshold is 0.0
# will perturb 47024
# threshold is 0.0
# will perturb 46067
# threshold is 0.0
# will perturb 45689
# threshold is 0.0
# will perturb 45233
# threshold is 0.0
# will perturb 43986
# threshold is 0.0
# will perturb 43973
# threshold is 0.0
# will perturb 43632
# threshold is 0.0
# will perturb 44148
# threshold is 0.0
# will perturb 45021
# threshold is 0.0
# will perturb 44814
# threshold is 0.0
# will perturb 42601
# threshold is 0.0
# will perturb 44446
# threshold is 0.0
# will perturb 47657
# threshold is 0.0
# will perturb 47442
# threshold is 0.0
# will perturb 42149
# threshold is 0.0
# will perturb 46646
# threshold is 0.0
# will perturb 46940
# threshold is 0.0
# will perturb 46549
# threshold is 0.0
# will perturb 46247
# threshold is 0.0
# will perturb 46863
# threshold is 0.0
# will perturb 46374
# threshold is 0.0
# will perturb 44965
# threshold is 0.0
# will perturb 43290
# threshold is 0.0
# will perturb 42039
# threshold is 0.0
# will perturb 44002
# threshold is 0.0
# will perturb 45269
# threshold is 0.0
# will perturb 44912
# threshold is 0.0
# will perturb 45852
# threshold is 0.0
# will perturb 43755
# threshold is 0.0006172941357363015
# will perturb 38400
# threshold is 0.0
# will perturb 44571
# threshold is 0.0
# will perturb 48118
# threshold is 0.0
# will perturb 48125
# threshold is 0.0
# will perturb 48818
# threshold is 0.0
# will perturb 47448
# threshold is 0.0
# will perturb 47209
# threshold is 0.0
# will perturb 46753
# threshold is 0.0
# will perturb 46248
# threshold is 0.0
# will perturb 45470
# threshold is 0.0
# will perturb 44351
# threshold is 0.0
# will perturb 43031
# threshold is 0.0
# will perturb 42990
# threshold is 0.0
# will perturb 46283
# threshold is 0.0
# will perturb 46273
# threshold is 0.0
# will perturb 44672
# threshold is 0.0
# will perturb 43514
# threshold is 0.0
# will perturb 44826
# threshold is 0.0
# will perturb 45950
# threshold is 0.0
# will perturb 47163
# threshold is 0.0
# will perturb 47610
# threshold is 0.0
# will perturb 47673
# threshold is 0.0
# will perturb 47099
# threshold is 0.0
# will perturb 47692
# threshold is 0.0
# will perturb 47158
# threshold is 0.0
# will perturb 44438
# threshold is 0.0
# will perturb 44576
# threshold is 0.0
# will perturb 44611
# threshold is 0.0
# will perturb 43326
# threshold is 0.0
# will perturb 42524
# threshold is 0.0
# will perturb 44978
# threshold is 0.0
# will perturb 45146
# threshold is 0.0
# will perturb 44031
# threshold is 0.0
# will perturb 43338
# threshold is 0.0
# will perturb 44217
# threshold is 0.0
# will perturb 45189
# threshold is 0.0
# will perturb 49120
# fps 19.73
# threshold is 0.0
# will perturb 47446
# threshold is 0.0
# will perturb 47069
# threshold is 0.0
# will perturb 44668
# threshold is 0.0
# will perturb 46249
# threshold is 0.0
# will perturb 46205
# threshold is 0.0
# will perturb 45486
# threshold is 0.0
# will perturb 45090
# threshold is 0.0
# will perturb 43758
# threshold is 0.0
# will perturb 42849
# threshold is 0.0
# will perturb 43999
# threshold is 0.0
# will perturb 44333
# threshold is 0.0
# will perturb 44142
# threshold is 0.0
# will perturb 44335
# threshold is 0.0
# will perturb 44776
# threshold is 0.0
# will perturb 43949
# threshold is 0.0
# will perturb 45998
# threshold is 0.0
# will perturb 47672
# threshold is 0.0
# will perturb 47638
# threshold is 0.0
# will perturb 46448
# threshold is 0.0
# will perturb 45768
# threshold is 0.0
# will perturb 46321
# threshold is 0.0
# will perturb 45611
# threshold is 0.0
# will perturb 46383
# threshold is 0.0
# will perturb 46268
# threshold is 0.0
# will perturb 43583
# threshold is 0.0
# will perturb 42907
# threshold is 0.0
# will perturb 44582
# threshold is 0.0
# will perturb 45334
# threshold is 0.0
# will perturb 41545
# threshold is 0.0
# will perturb 44000
# threshold is 0.0
# will perturb 44373
# threshold is 0.0
# will perturb 44050
# threshold is 0.0
# will perturb 43498
# threshold is 0.0
# will perturb 45756
# threshold is 0.0
# will perturb 48950
# threshold is 0.0
# will perturb 46395
# threshold is 0.0
# will perturb 45987
# threshold is 0.0
# will perturb 45729
# threshold is 0.0
# will perturb 46135
# threshold is 0.0
# will perturb 46773
# threshold is 0.0
# will perturb 46353
# threshold is 0.0
# will perturb 46044
# threshold is 0.0
# will perturb 44557
# threshold is 0.0
# will perturb 43846
# threshold is 0.0
# will perturb 42039
# threshold is 0.0
# will perturb 45151
# threshold is 0.0
# will perturb 45115
# threshold is 0.0
# will perturb 45496
# threshold is 0.0
# will perturb 44635
# threshold is 0.0
# will perturb 44258
# threshold is 0.0
# will perturb 47372
# threshold is 0.0
# will perturb 48067
# threshold is 0.0
# will perturb 48358
# threshold is 0.0
# will perturb 48093
# threshold is 0.0
# will perturb 46425
# threshold is 0.0
# will perturb 45023
# threshold is 0.0
# will perturb 45381
# threshold is 0.0
# will perturb 44528
# threshold is 0.0
# will perturb 45266
# threshold is 0.0
# will perturb 43352
# threshold is 0.0
# will perturb 44006
# threshold is 0.0
# will perturb 45484
# threshold is 0.0
# will perturb 45010
# threshold is 0.0
# will perturb 44981
# threshold is 0.0
# will perturb 45151
# threshold is 0.0
# will perturb 44530
# threshold is 0.0
# will perturb 46021
# threshold is 0.0
# will perturb 48112
# threshold is 0.0
# will perturb 47608
# threshold is 0.0
# will perturb 48358
# threshold is 0.0
# will perturb 46085
# threshold is 0.0
# will perturb 45891
# threshold is 0.0
# will perturb 45910
# threshold is 0.0
# will perturb 45346
# threshold is 0.0
# will perturb 44935
# threshold is 0.0
# will perturb 42295
# threshold is 0.0
# will perturb 42574
# threshold is 0.0
# will perturb 45310
# threshold is 0.0
# will perturb 45601
# threshold is 0.0
# will perturb 45252
# threshold is 0.0
# will perturb 44483
# threshold is 0.0
# will perturb 43107
# threshold is 0.0
# will perturb 43762
# threshold is 0.0
# will perturb 45754
# threshold is 0.0
# will perturb 49165
# threshold is 0.0
# will perturb 47982
# threshold is 0.0
# will perturb 47719
# threshold is 0.0
# will perturb 45073
# threshold is 0.0
# will perturb 46015
# threshold is 0.0
# will perturb 45631
# threshold is 0.0
# will perturb 44926
# threshold is 0.0
# will perturb 44253
# threshold is 0.0
# will perturb 44183
# threshold is 0.0
# will perturb 42482
# threshold is 0.0
# will perturb 43487
# threshold is 0.0
# will perturb 44389
# fps 19.74
# threshold is 0.0
# will perturb 44883
# threshold is 0.0
# will perturb 45626
# threshold is 0.0
# will perturb 45550
# threshold is 0.0
# will perturb 44538
# threshold is 0.0
# will perturb 45505
# threshold is 0.0
# will perturb 46873
# threshold is 0.0
# will perturb 45867
# threshold is 0.0
# will perturb 46411
# threshold is 0.0
# will perturb 45850
# threshold is 0.0
# will perturb 46428
# threshold is 0.0
# will perturb 46440
# threshold is 0.0
# will perturb 43725
# threshold is 0.0
# will perturb 44767
# threshold is 0.0
# will perturb 43623
# threshold is 0.0
# will perturb 41976
# threshold is 0.0
# will perturb 43246
# threshold is 0.0
# will perturb 42684
# threshold is 0.0
# will perturb 43118
# threshold is 0.0
# will perturb 43601
# threshold is 0.0
# will perturb 43277
# threshold is 0.0
# will perturb 45069
# threshold is 0.0
# will perturb 46483
# threshold is 0.0
# will perturb 48441
# threshold is 0.0
# will perturb 46665
# threshold is 0.0
# will perturb 47264
# threshold is 0.0
# will perturb 46606
# threshold is 0.0
# will perturb 46752
# threshold is 0.0
# will perturb 45803
# threshold is 0.0
# will perturb 46128
# threshold is 0.0
# will perturb 44414
# threshold is 0.0
# will perturb 43125
# threshold is 0.0
# will perturb 41739
# threshold is 0.0
# will perturb 44773
# threshold is 0.0
# will perturb 45550
# threshold is 0.0
# will perturb 45057
# threshold is 0.0
# will perturb 43496
# threshold is 0.0
# will perturb 45368
# threshold is 0.0
# will perturb 47012
# threshold is 0.0
# will perturb 47899
# threshold is 0.0
# will perturb 48042
# threshold is 0.0
# will perturb 47738
# threshold is 0.0
# will perturb 47389
# threshold is 0.0
# will perturb 45082
# threshold is 0.0
# will perturb 44968
# threshold is 0.0
# will perturb 44743
# threshold is 0.0
# will perturb 43113
# threshold is 0.0
# will perturb 45517
# threshold is 0.0
# will perturb 44622
# threshold is 0.0
# will perturb 46520
# threshold is 0.0
# will perturb 45586
# threshold is 0.0
# will perturb 44702
# threshold is 0.0
# will perturb 46003
# threshold is 0.0
# will perturb 48983
# threshold is 0.0
# will perturb 47388
# threshold is 0.0
# will perturb 49082
# threshold is 0.0
# will perturb 50330
# threshold is 0.0
# will perturb 48543
# threshold is 0.0
# will perturb 44455
# threshold is 0.0
# will perturb 48347
# threshold is 0.0
# will perturb 46907
# threshold is 0.0
# will perturb 46452
# threshold is 0.0
# will perturb 44721
# threshold is 0.0
# will perturb 46698
# threshold is 0.0
# will perturb 47978
# threshold is 0.0
# will perturb 49882
# threshold is 0.0
# will perturb 49697
# threshold is 0.0
# will perturb 51787
# threshold is 0.0
# will perturb 59539
# threshold is 0.0
# will perturb 69426
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.46
# ----- Finished Perturbation-Controller set up -----
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# INFO:SDSandBoxSimulator:+++++ SDSandBox Simulator Got Interrupted +++++
# INFO:DonkeySimMsgHandler:DonkeySimMsgHandler: +++++ Warning: Donkey Sim Disconnected +++++
# INFO:DonkeyProcess:Closing donkey sim subprocess
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Documents/BachelorWInfo/Robustness-SDC/PerturbationDrive/examples/self_driving_sandbox_donkey/sdsandbox_simulator.py:95, in SDSandboxSimulator.simulate_scanario(self, agent, scenario, perturbation_controller)
#      93 try:
#      94     # TODO: Play around with this value
# ---> 95     time.sleep(0.01)
#      96     # we provide the actions and perturbed image here
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 57
#      55 # update attention map
#      56 attention_map["attention_perturbation"] = "perturb_random_n_attention_regions"
# ---> 57 res = benchmark.simulate_scenarios(
#      58     scenarios=scenarios,
#      59     attention_map=attention_map,
#      60     log_dir=None,
#      61 )
#      62 del res
#      63 gc.collect()
#
# File ~/Documents/BachelorWInfo/Robustness-SDC/PerturbationDrive/perturbationdrive/perturbationdrive.py:281, in PerturbationDrive.simulate_scenarios(self, scenarios, attention_map, log_dir, overwrite_logs, image_size)
#     279 # iterate over all scenarios
#     280 for scenario in scenarios:
# --> 281     outcome = self.simulator.simulate_scanario(
#     282         self.ads, scenario=scenario, perturbation_controller=iamge_perturbation
#     283     )
#     284     outcomes.append(outcome)
#     285     time.sleep(2.0)
#
# File ~/Documents/BachelorWInfo/Robustness-SDC/PerturbationDrive/examples/self_driving_sandbox_donkey/sdsandbox_simulator.py:132, in SDSandboxSimulator.simulate_scanario(self, agent, scenario, perturbation_controller)
#     128         self.logger.info(
#     129             f"{5 * '+'} SDSandBox Simulator Got Interrupted {5 * '+'}"
#     130         )
#     131         self.client.stop()
# --> 132         raise KeyboardInterrupt
#     133 print("SDSandBox: Finished scenario")
#     134 # break
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Test Static'' Perturbation

# %%
static_perturbations = [
    "static_snow_filter",
    "static_rain_filter",
    "static_object_overlay",
    "static_sun_filter",
    "static_smoke_filter",
]

# %%
from perturbationdrive import Scenario
import gc
import random

random.seed(42)
dave_aug = Dave2Agent(model_path="./examples/models/dave_static_aug.h5")
dave_aug.name = "FILTER-AUG-DAVE2"

try:
    benchmark = PerturbationDrive(simulator=simulator_sdsandbox, ads=dave_aug)
    benchmark.simulator.connect()
    starting_pos = benchmark.simulator.initial_pos

    # init all scenarios
    scenarios = []
    counter = 0
    # iterate over all agents
    for angle, segment in zip(angles, segments):
        # run all perturbations for each road
        waypoints = road_gen.generate(
            starting_pos=starting_pos, angles=angle, seg_length=segment
        )
        scenarios = []
        for func in static_perturbations:
            for i in range(5):
                scenarios.append(
                    Scenario(
                        waypoints=waypoints,
                        perturbation_function=func,
                        perturbation_scale=i,
                    )
                )
        print(f"Starting Agent {dave_aug.name} on road {angle}")
        # run the benchmark
        res = benchmark.simulate_scenarios(
            scenarios=scenarios,
            attention_map=attention_map,
            log_dir=f"./logs/donkey_static2__road{counter}_{dave_aug.name}.json",
        )
        del res
        counter += 1
        gc.collect()
except Exception as e:
    print(e)
finally:
    benchmark.simulator.tear_down()
# Out:
# Using model: ./examples/models/dave_static_aug.h5
# INFO:DonkeyProcess:This is the launch string /Users/hannesleonhard/Documents/BachelorWInfo/Robustness-SDC/PerturbationDrive/./examples/self_driving_sandbox_donkey/sim/donkey-sim.app/Contents/MacOS/Simulator
# [UnityMemory] Configuration Parameters - Can be set up in boot.config
#     "memorysetup-bucket-allocator-granularity=16"
#     "memorysetup-bucket-allocator-bucket-count=8"
#     "memorysetup-bucket-allocator-block-size=4194304"
#     "memorysetup-bucket-allocator-block-count=1"
#     "memorysetup-main-allocator-block-size=16777216"
#     "memorysetup-thread-allocator-block-size=16777216"
#     "memorysetup-gfx-main-allocator-block-size=16777216"
#     "memorysetup-gfx-thread-allocator-block-size=16777216"
#     "memorysetup-cache-allocator-block-size=4194304"
#     "memorysetup-typetree-allocator-block-size=2097152"
#     "memorysetup-profiler-bucket-allocator-granularity=16"
#     "memorysetup-profiler-bucket-allocator-bucket-count=8"
#     "memorysetup-profiler-bucket-allocator-block-size=4194304"
#     "memorysetup-profiler-bucket-allocator-block-count=1"
#     "memorysetup-profiler-allocator-block-size=16777216"
#     "memorysetup-profiler-editor-allocator-block-size=1048576"
#     "memorysetup-temp-allocator-size-main=4194304"
#     "memorysetup-job-temp-allocator-block-size=2097152"
#     "memorysetup-job-temp-allocator-block-size-background=1048576"
#     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
#     "memorysetup-allocator-temp-initial-block-size-main=262144"
#     "memorysetup-allocator-temp-initial-block-size-worker=262144"
#     "memorysetup-temp-allocator-size-background-worker=32768"
#     "memorysetup-temp-allocator-size-job-worker=262144"
#     "memorysetup-temp-allocator-size-preload-manager=262144"
#     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
#     "memorysetup-temp-allocator-size-audio-worker=65536"
#     "memorysetup-temp-allocator-size-cloud-worker=32768"
#     "memorysetup-temp-allocator-size-gfx=262144"
# INFO:DonkeyProcess:donkey subprocess started
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:SDSandBoxSimulator:Waiting for inital obs
# INFO:DonkeySimMsgHandler:DonkeySimMsgHandler: ----- Car Created With Data {'msg_type': 'car_loaded'} -----
# Starting Agent FILTER-AUG-DAVE2 on road [0, 0, 0, 0, 0, 0, 0, 0]
# ----- Finished Perturbation-Controller set up -----
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 18.81
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.69
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.75
# fps 19.55
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.45
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.74
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.46
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.69
# fps 19.66
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.70
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.39
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.69
# fps 19.72
# fps 19.68
# fps 19.70
# fps 19.69
# fps 19.71
# fps 19.64
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.73
# fps 17.54
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.55
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.68
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.68
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.69
# fps 19.72
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.73
# fps 19.68
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.69
# fps 19.65
# fps 19.72
# fps 19.71
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.46
# fps 19.81
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.69
# fps 19.69
# fps 19.70
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.59
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.46
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.65
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.68
# fps 19.69
# fps 19.70
# fps 19.69
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.64
# fps 19.75
# fps 19.72
# fps 19.72
# fps 19.67
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.72
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.69
# fps 19.69
# fps 19.72
# fps 19.69
# fps 19.69
# fps 19.70
# fps 19.71
# fps 19.63
# fps 19.71
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.74
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.69
# fps 19.68
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.74
# fps 19.69
# fps 19.69
# fps 19.70
# fps 19.70
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.69
# fps 19.72
# fps 19.68
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.69
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.69
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.67
# fps 19.70
# INFO:DonkeySimMsgHandler:DonkeySimMsgHandler: +++++ Warning: Donkey Sim Message Closed by SimClient +++++
# INFO:DonkeySimMsgHandler:DonkeySimMsgHandler: +++++ Warning: Donkey Sim Message Stoped +++++
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.69
# fps 19.71
# fps 19.69
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.68
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.74
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.69
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.64
# fps 19.76
# fps 19.71
# fps 19.69
# fps 19.68
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.69
# fps 19.74
# fps 19.72
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.64
# Starting Agent FILTER-AUG-DAVE2 on road [0, -20, -10, -11, -13, -25, -24, 4]
# ----- Finished Perturbation-Controller set up -----
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.85
# fps 19.73
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.74
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.74
# fps 19.72
# fps 19.72
# fps 19.72
# fps 17.58
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 17.15
# fps 19.74
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.70
# fps 19.68
# fps 19.68
# fps 19.39
# fps 19.73
# fps 19.70
# fps 19.61
# fps 19.69
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.69
# fps 19.73
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.58
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.69
# fps 19.71
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.71
# fps 19.72
# fps 19.69
# fps 19.72
# fps 19.72
# fps 19.68
# fps 19.69
# fps 19.70
# fps 19.72
# fps 19.69
# fps 19.73
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.70
# fps 19.71
# fps 19.69
# fps 19.68
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.64
# fps 19.74
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.69
# fps 19.68
# fps 19.74
# fps 19.72
# fps 19.69
# fps 17.22
# fps 19.72
# fps 19.69
# fps 19.68
# fps 19.70
# fps 19.70
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.70
# fps 19.69
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.63
# fps 19.71
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.54
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.70
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.70
# fps 19.73
# fps 19.73
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.67
# fps 19.70
# fps 19.71
# fps 19.68
# fps 19.73
# fps 19.71
# fps 19.69
# fps 19.68
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.74
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.69
# fps 19.69
# fps 19.69
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.75
# fps 19.69
# fps 19.73
# fps 19.69
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.68
# fps 19.75
# fps 19.57
# fps 19.73
# fps 19.68
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.73
# fps 19.72
# fps 19.68
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.67
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.57
# fps 19.67
# fps 19.80
# fps 19.67
# fps 19.73
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.64
# fps 19.72
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.57
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.68
# fps 19.72
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.68
# fps 19.70
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.72
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.69
# fps 19.69
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.70
# fps 19.69
# fps 19.69
# fps 19.69
# fps 19.71
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.70
# fps 19.60
# fps 19.63
# fps 19.71
# fps 19.70
# fps 19.68
# fps 19.73
# fps 19.70
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.70
# fps 19.68
# fps 19.69
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.69
# fps 19.71
# fps 19.70
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# Starting Agent FILTER-AUG-DAVE2 on road [0, 24, 24, -5, -7, -24, -20, 17]
# ----- Finished Perturbation-Controller set up -----
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.73
# fps 19.65
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.69
# fps 19.71
# fps 19.69
# fps 19.69
# fps 19.70
# fps 19.72
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.75
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.69
# fps 19.72
# fps 19.69
# fps 19.69
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.72
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.73
# fps 19.70
# fps 19.49
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# fps 17.25
# fps 19.72
# fps 19.71
# fps 19.68
# fps 19.65
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.74
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.40
# fps 19.69
# fps 19.68
# fps 19.72
# fps 19.72
# fps 19.68
# fps 19.72
# fps 19.73
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.74
# fps 19.73
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.66
# fps 19.71
# fps 19.70
# fps 19.68
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.67
# fps 19.73
# fps 19.70
# fps 19.74
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.75
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.63
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.69
# fps 18.43
# fps 19.73
# fps 19.58
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.66
# fps 19.71
# fps 19.66
# fps 19.65
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.69
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.66
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.71
# fps 19.59
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.69
# fps 19.73
# fps 19.70
# fps 19.72
# fps 19.69
# fps 19.65
# fps 19.70
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.67
# fps 19.73
# fps 19.70
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.75
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.51
# fps 19.72
# fps 19.73
# fps 19.69
# fps 19.69
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.72
# fps 19.69
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.66
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.69
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.68
# fps 19.72
# fps 19.72
# fps 19.74
# fps 19.74
# fps 19.71
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.74
# fps 19.71
# fps 19.69
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.65
# fps 19.71
# fps 19.73
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.72
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.74
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.66
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.74
# fps 19.71
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.70
# fps 19.71
# fps 19.68
# fps 19.70
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.69
# fps 19.73
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.76
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.68
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.68
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.72
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.70
# fps 19.69
# fps 19.72
# fps 19.73
# fps 19.75
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.73
# fps 19.64
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.74
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.68
# fps 19.63
# fps 19.70
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.28
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.69
# fps 19.60
# fps 19.69
# fps 19.72
# fps 19.69
# fps 19.69
# fps 19.73
# fps 19.74
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.73
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# Starting Agent FILTER-AUG-DAVE2 on road [0, 6, 8, 20, -3, 20, -13, -27]
# fps 19.69
# ----- Finished Perturbation-Controller set up -----
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.73
# fps 19.51
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.61
# fps 19.74
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.69
# fps 19.73
# fps 19.67
# fps 19.66
# fps 19.70
# fps 19.47
# fps 9.91
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 14.90
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 14.78
# fps 19.69
# fps 16.81
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.63
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.72
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.68
# fps 19.71
# fps 19.73
# fps 19.70
# fps 13.30
# fps 11.88
# fps 14.88
# fps 15.02
# fps 10.89
# fps 19.72
# fps 19.71
# fps 16.95
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.73
# fps 19.71
# fps 16.95
# fps 13.18
# fps 16.95
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.70
# fps 17.00
# fps 19.70
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 14.92
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 11.89
# fps 13.32
# fps 9.21
# fps 11.91
# fps 19.70
# fps 14.88
# fps 10.83
# fps 13.30
# fps 15.04
# fps 16.99
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 16.95
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 17.03
# fps 9.26
# fps 16.95
# fps 15.01
# fps 10.90
# fps 13.17
# fps 14.91
# fps 19.72
# fps 16.94
# fps 13.26
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 11.88
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 16.91
# fps 19.75
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.70
# fps 14.83
# fps 16.82
# fps 19.71
# fps 14.81
# fps 14.94
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 11.81
# fps 16.98
# fps 12.03
# fps 16.99
# fps 19.70
# fps 14.89
# fps 16.95
# fps 19.72
# fps 19.74
# fps 19.68
# fps 14.78
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 10.97
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.71
# fps 14.93
# fps 14.77
# fps 19.88
# fps 19.71
# fps 13.21
# fps 19.66
# fps 17.00
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.65
# fps 19.74
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.69
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.70
# fps 19.73
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.74
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.55
# fps 19.90
# fps 19.66
# fps 19.80
# fps 19.73
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.72
# fps 19.71
# fps 19.71
# fps 17.56
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.69
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 17.45
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.68
# fps 19.70
# fps 19.70
# fps 19.68
# fps 19.71
# fps 19.72
# fps 19.70
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.48
# fps 19.77
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.69
# fps 19.69
# fps 19.72
# fps 19.52
# fps 19.72
# fps 19.66
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.66
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.67
# fps 19.71
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.72
# fps 19.69
# fps 19.68
# fps 19.71
# fps 19.68
# fps 19.54
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.68
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.66
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.69
# fps 19.73
# fps 19.71
# fps 19.60
# fps 19.69
# fps 19.63
# fps 19.70
# fps 19.73
# fps 19.69
# fps 19.62
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.61
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.64
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.76
# fps 19.70
# fps 19.68
# fps 19.78
# fps 19.73
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.68
# fps 19.71
# fps 19.49
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# Starting Agent FILTER-AUG-DAVE2 on road [0, -2, -30, -8, 2, 2, 4, -30]
# fps 19.09
# ----- Finished Perturbation-Controller set up -----
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.73
# fps 19.74
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.64
# fps 19.70
# fps 19.69
# fps 19.63
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.59
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.69
# fps 19.71
# fps 19.73
# fps 19.67
# fps 19.67
# fps 19.73
# fps 19.69
# fps 19.69
# fps 19.64
# fps 19.67
# fps 19.69
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.69
# fps 19.73
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.65
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.63
# fps 19.62
# fps 19.72
# fps 19.70
# fps 19.73
# fps 19.72
# fps 19.72
# fps 17.61
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.72
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.73
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.70
# fps 19.70
# fps 19.69
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.69
# fps 19.72
# fps 19.73
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.74
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.74
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.69
# fps 19.70
# fps 19.69
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.72
# fps 19.71
# fps 19.53
# fps 19.70
# fps 19.65
# fps 19.70
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.70
# fps 19.67
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.66
# fps 19.71
# fps 19.70
# fps 19.67
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.72
# fps 19.70
# fps 19.74
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.68
# fps 19.68
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.68
# fps 19.68
# fps 19.72
# fps 19.71
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.74
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.69
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.73
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.69
# fps 19.70
# fps 19.69
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.68
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.74
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.74
# fps 19.70
# fps 19.76
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.65
# fps 19.68
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.66
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.73
# fps 19.70
# fps 19.72
# fps 19.68
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.72
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.72
# fps 19.69
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.73
# fps 19.69
# fps 19.72
# fps 19.73
# fps 19.70
# fps 19.73
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.69
# fps 19.70
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# Starting Agent FILTER-AUG-DAVE2 on road [0, 0, 27, 35, -35, -35, -6, -35]
# fps 19.73
# ----- Finished Perturbation-Controller set up -----
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.74
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.76
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.68
# fps 19.73
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.70
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.72
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.75
# fps 19.69
# fps 19.35
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.73
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.74
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.73
# fps 19.70
# fps 19.61
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.73
# fps 19.70
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.65
# fps 19.71
# fps 19.70
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.67
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.73
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.60
# fps 19.84
# fps 19.70
# fps 19.72
# fps 19.65
# fps 19.73
# fps 19.69
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.75
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.74
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.69
# fps 19.69
# fps 19.71
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.74
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.69
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.65
# fps 19.74
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.68
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.67
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.60
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.69
# fps 19.70
# fps 19.70
# fps 19.67
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.73
# fps 19.70
# fps 19.70
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.69
# fps 17.25
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.62
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.69
# fps 19.69
# fps 19.73
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.69
# fps 19.65
# fps 19.72
# fps 19.72
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.75
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# Starting Agent FILTER-AUG-DAVE2 on road [0, -27, -20, 35, 23, -3, 4, -35]
# fps 19.70
# ----- Finished Perturbation-Controller set up -----
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.73
# fps 19.72
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.71
# fps 19.73
# fps 19.70
# fps 19.70
# fps 19.68
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.66
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.68
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.69
# fps 19.69
# fps 19.69
# fps 19.69
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.71
# fps 19.74
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.69
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.65
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.71
# fps 19.65
# fps 19.69
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.59
# fps 19.68
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.71
# fps 19.71
# fps 17.48
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.75
# fps 19.68
# fps 19.35
# fps 19.62
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.61
# fps 19.76
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.68
# fps 19.73
# fps 19.74
# fps 19.69
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.70
# fps 19.71
# fps 19.69
# fps 19.73
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.74
# fps 19.75
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.69
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.66
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.57
# fps 19.69
# fps 19.49
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.69
# fps 19.70
# fps 19.69
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.69
# fps 19.70
# fps 19.54
# fps 19.68
# fps 19.73
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.74
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.71
# fps 19.68
# fps 19.63
# fps 19.75
# fps 18.63
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.70
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.68
# fps 19.73
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.74
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.73
# fps 19.71
# fps 19.60
# fps 19.80
# fps 19.77
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.70
# fps 19.75
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.75
# fps 19.74
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.73
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.73
# fps 19.73
# fps 19.69
# fps 19.70
# fps 19.71
# fps 19.69
# fps 19.69
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.69
# fps 19.73
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.72
# fps 19.73
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.69
# fps 19.68
# fps 19.68
# fps 19.72
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.71
# fps 19.70
# fps 19.68
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.65
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# Starting Agent FILTER-AUG-DAVE2 on road [0, 30, 30, -30, 32, -32, 25, -12]
# fps 19.75
# ----- Finished Perturbation-Controller set up -----
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.66
# fps 19.20
# fps 19.69
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.76
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.73
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.75
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.67
# fps 19.67
# fps 19.67
# fps 19.70
# fps 19.68
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.74
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.71
# fps 19.71
# fps 19.71
# ...
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.61
# fps 19.71
# fps 19.69
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.70
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.73
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.72
# fps 19.72
# fps 19.69
# fps 19.71
# fps 19.73
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.70
# fps 19.73
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.66
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.74
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.66
# fps 19.74
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.65
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.74
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# Starting Agent FILTER-AUG-DAVE2 on road [0, -35, -20, -35, 35, 35, 35, -35]
# fps 19.74
# ----- Finished Perturbation-Controller set up -----
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.74
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.69
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.73
# fps 19.73
# fps 19.69
# fps 19.73
# fps 19.73
# fps 19.75
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.69
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.74
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.72
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.68
# fps 19.71
# fps 19.73
# fps 19.74
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.65
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.74
# fps 19.71
# fps 19.73
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.73
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.63
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.68
# fps 19.71
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.69
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.57
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.61
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.15
# fps 19.58
# fps 19.52
# fps 19.70
# fps 19.72
# fps 19.74
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.70
# fps 17.35
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.67
# fps 19.72
# fps 19.69
# fps 19.30
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.70
# fps 19.71
# fps 19.51
# fps 19.69
# fps 19.74
# fps 19.56
# fps 19.69
# fps 19.70
# fps 19.70
# fps 19.62
# fps 19.71
# fps 19.64
# fps 19.68
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.71
# fps 19.60
# fps 19.72
# fps 19.62
# fps 19.67
# fps 19.70
# fps 19.72
# fps 19.61
# fps 19.74
# fps 19.67
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.59
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.66
# fps 19.70
# fps 19.64
# fps 19.72
# fps 19.69
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.68
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.72
# fps 17.63
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.71
# fps 19.69
# fps 19.74
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.76
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.69
# fps 19.73
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.69
# fps 19.73
# fps 19.71
# fps 19.74
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.72
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.73
# fps 19.73
# fps 19.72
# fps 19.69
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.59
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.73
# fps 17.41
# fps 19.69
# fps 19.73
# fps 17.55
# fps 19.74
# fps 17.51
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.71
# fps 19.71
# fps 17.68
# fps 19.71
# fps 19.64
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.33
# fps 19.73
# fps 19.68
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.71
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.70
# fps 17.65
# fps 19.69
# fps 19.71
# fps 19.66
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.66
# Starting Agent FILTER-AUG-DAVE2 on road [0, -35, 0, -17, -35, 35, 6, -22]
# ----- Finished Perturbation-Controller set up -----
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.75
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.52
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.72
# fps 19.73
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.71
# fps 17.13
# fps 19.64
# fps 16.69
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.66
# fps 19.71
# fps 19.66
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.64
# fps 19.64
# fps 19.52
# fps 19.71
# fps 19.71
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.72
# fps 19.69
# fps 19.68
# fps 19.67
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.73
# fps 19.71
# fps 19.69
# fps 19.71
# fps 19.67
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.72
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.71
# fps 19.69
# fps 19.72
# fps 19.72
# fps 19.74
# fps 19.70
# fps 17.33
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.73
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.76
# fps 19.68
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.74
# fps 19.72
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.76
# fps 19.73
# fps 17.66
# fps 19.70
# fps 19.70
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.73
# fps 19.73
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.76
# fps 19.74
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.73
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.74
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.76
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.70
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.70
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.68
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.65
# fps 19.72
# fps 19.70
# fps 19.71
# fps 19.71
# fps 19.70
# fps 19.69
# fps 19.67
# fps 19.78
# fps 19.71
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.69
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.71
# fps 19.71
# fps 19.72
# fps 17.53
# fps 19.70
# fps 19.69
# fps 19.69
# fps 19.69
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.70
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.69
# fps 19.71
# fps 19.73
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.70
# fps 19.72
# fps 19.73
# fps 19.71
# fps 19.55
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.74
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.69
# fps 19.75
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.74
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.71
# fps 19.73
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.71
# fps 19.73
# fps 19.73
# fps 19.68
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.70
# fps 19.72
# fps 19.74
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.71
# fps 19.45
# fps 19.70
# fps 19.70
# fps 19.72
# fps 19.69
# fps 19.72
# fps 19.69
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.70
# fps 19.76
# fps 19.73
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.73
# fps 19.73
# fps 19.73
# fps 19.71
# fps 19.72
# fps 19.73
# fps 19.72
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.76
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.72
# fps 19.70
# fps 19.69
# fps 19.73
# fps 19.73
# fps 19.73
# fps 19.73
# fps 19.74
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.77
# fps 19.73
# fps 19.71
# fps 19.73
# fps 19.73
# fps 19.72
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.74
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.74
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.73
# fps 19.71
# fps 19.71
# fps 19.73
# fps 19.72
# fps 19.73
# fps 19.69
# fps 19.74
# fps 19.70
# fps 19.72
# fps 19.74
# fps 19.71
# fps 19.74
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.75
# fps 19.75
# fps 19.71
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.69
# fps 19.70
# fps 19.73
# fps 19.71
# fps 19.70
# fps 19.71
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.70
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.77
# fps 19.71
# fps 19.72
# fps 19.70
# fps 19.70
# fps 19.74
# fps 19.69
# fps 19.72
# fps 19.71
# fps 19.73
# fps 19.74
# fps 19.73
# fps 19.72
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.68
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.74
# fps 19.72
# fps 19.76
# fps 19.73
# fps 19.73
# fps 19.72
# fps 19.71
# fps 19.72
# fps 19.71
# fps 19.71
# fps 19.69
# fps 19.70
# fps 19.71
# fps 19.70
# fps 19.70
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# INFO:SDSandBoxSimulator:Reset the scenario
# fps 19.67
# fps 19.74
# fps 19.70
# fps 19.72
# fps 19.77
# fps 19.75
# fps 19.70
# fps 19.72
# fps 19.72
# fps 19.73
# fps 19.69
# fps 19.73
# fps 19.71
# fps 19.68
# fps 19.69
# fps 19.72
# INFO:SDSandBoxSimulator:SDSandBox: Done
# SDSandBox: Finished scenario
# fps 19.67
# INFO:DonkeySimMsgHandler:DonkeySimMsgHandler: +++++ Warning: Donkey Sim Disconnected +++++
# INFO:DonkeyProcess:Closing donkey sim subprocess
# Exception: [Errno 54] Connection reset by peer
# CRITICAL:DonkeySimMsgHandler:DonkeySimMsgHandler: +++++ Warning: Donkey Sim Aborted +++++
# INFO:DonkeySimMsgHandler:DonkeySimMsgHandler: +++++ Warning: Donkey Sim Message Stoped +++++
